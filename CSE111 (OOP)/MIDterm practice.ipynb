# %%
class Dominos:
    dict_beef={}
    dict_chicken={}
    dict_cheese={}
    
    def __init__(self,place):
        self.place=place.split( )
        print(self.place[0]+'. The Pizza Delivery Experts')
        
    def addPizza(self,other1,other2=None):
        if other2 != None:
            if 'beef' in other1.info[0]:
                Dominos.dict_beef[other1.info[0]]=other1.info 
            if 'chicken' in other1.info[0]:
                Dominos.dict_chicken[other1.info[0]]=other1.info
            else:
                Dominos.dictcheese[other1.info[0]]=other1.info
        else:
            if 'beef' in other1.info[0]:
                Dominos.dict_beef[other1.info[0]]=other1.info 
            if 'chicken' in other1.info[0]:
                Dominos.dict_chicken[other1.info[0]]=other1.info
            else:
                Dominos.dict_cheese[other1.info[0]]=other1.info
            
    def showMenu(self):
        print('Total number of pizzas: ',len(Dominos.dict_beef)+len(Dominos.dict_chicken)+len(Dominos.dict_cheese))
        for i,k in Dominos.dict_beef().items():
            print('Name-',i,'Toppings:',k)
            
        for i,k in Dominos.dict_chicken().items():
            print('Name-',i,'Toppings:',k)
        
        for i,k in Dominos.dict_cheese().items():
            print('Name-',i,'Toppings:',k)
        
class Pizza:
    def __init__(self,*info):
        self.info=info
        if len(info)==1:
            print('A pizza without toppings cannot be created.')
        
    def setToppings(self,*topping):
        Dominos.dict_beef[self.info[0]]=topping

dom = Dominos("Domino's Pizza")
print("1.=================================")
p1 = Pizza("Spicy Chicken","Spicy Chicken","Onion","Capsicum")
dom.addPizza(p1)
p2 = Pizza("Margherita","Mozzarella Cheese")
print("2.=================================")
p3 = Pizza("Beef Kala Bhuna")
print("3.=================================")
p3.setToppings("Curried Beef","Capsicum","Paprika","Onion")
print("4.=================================")
dom.addPizza(p2,p3)
p4 = Pizza("Chicken Dominator","Barbecue Chicken,Spicy Chicken,Grilled Chicken")
p5 = Pizza("Beefzza","Minced Beef","Beef Pepperoni","Onion","Jalapeno")
dom.addPizza(p4,p5)
print("5.=================================")
dom.showMenu()
print("6.=================================")
# Out:
# Domino's. The Pizza Delivery Experts
# 1.=================================
# 2.=================================
# A pizza without toppings cannot be created.
# 3.=================================
# 4.=================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0313a3ad878d> in <module>
#      54 p3.setToppings("Curried Beef","Capsicum","Paprika","Onion")
#      55 print("4.=================================")
# ---> 56 dom.addPizza(p2,p3)
#      57 p4 = Pizza("Chicken Dominator","Barbecue Chicken,Spicy Chicken,Grilled Chicken")
#      58 p5 = Pizza("Beefzza","Minced Beef","Beef Pepperoni","Onion","Jalapeno")
#
# <ipython-input-11-0313a3ad878d> in addPizza(self, other1, other2)
#      15                 Dominos.dict_chicken[other1.info[0]]=other1.info
#      16             else:
# ---> 17                 Dominos.dictcheese[other1.info[0]]=other1.info
#      18         else:
#      19             if 'beef' in other1.info[0]:
#
# AttributeError: type object 'Dominos' has no attribute 'dictcheese'

# %%
Domino’s. The Pizza Delivery Experts.
1.======================================
2.======================================
A pizza without toppings cannot be created.
3.======================================
Toppings added to Beef Kala Bhuna pizza.
4.======================================
5.======================================
Total number of pizzas: 5
Chicken Pizza:2
Name:Spicy Chicken, Toppings: ['Spicy Chicken', 'Onion', 'Capsicum']
Name:Chicken Dominator, Toppings: ['Barbecue Chicken,Spicy Chicken,Grilled Chicken']

Beef Pizza:2
Name:Beef Kala Bhuna, Toppings: ['Curried Beef', 'Capsicum', 'Paprika', 'Onion']
Name:Beefzza, Toppings: ['Minced Beef', 'Beef Pepperoni', 'Onion', 'Jalapeno']

Cheese Pizza: 1
Name:Margherita, Toppings: ['Mozzarella Cheese']
6.======================================

# %%
my_tuple = ("NoTimeToDie DanielCraige UK", "MissionImpossible TomCruise USA", "TopGun TomCruise USA", "Troy BradPitt USA", "Skyfall DanielCraige UK", "TheTheoryOfEveryting EddieRedmayne UK", "FantasticBeast EddieRedmayne UK", "Seven BradPitt USA")

dict1={'USA':[],'UK':[]}

for i in my_tuple:
    list1=i.split(' ')
    
    if list1[2] == 'USA':
        str1='2'
        if list1[1] == 'DanielCraig':
            str1+='01'
        elif list1[1] == 'TomCruise':
            str1+='02'
        elif list1[1] == 'BradPitt':
            str1+='03'
        else:
            str1+='04'
            
        str1+=str(my_tuple.index(i))
        dict1['USA'].append((list1[0],int(str1)))
        
    if list1[2] == 'UK':
        str1='1'
        if list1[1] == 'DanielCraig':
            str1+='01'
        elif list1[1] == 'TomCruise':
            str1+='02'
        elif list1[1] == 'BradPitt':
            str1+='03'
        else:
            str1+='04'
            
        str1+=str(my_tuple.index(i))
        dict1['UK'].append((list1[0],str1))
        
print(dict1)
# Out:
# {'USA': [('MissionImpossible', 2021), ('TopGun', 2022), ('Troy', 2033), ('Seven', 2037)], 'UK': [('NoTimeToDie', '1040'), ('Skyfall', '1044'), ('TheTheoryOfEveryting', '1045'), ('FantasticBeast', '1046')]}

# %%
class Series:
    
    def __init__(self,name,year,language='English'):
        self.name=name
        self.year=year
        self.language=language
        self.character_list=[]
        
    def calculateCost(self):
        count1=self.character_list.count("Main character")
        count2=self.character_list.count('Supporting character')
        self.amount=(count1*10000)+(count2*5000)
        if self.amount == 0:
            print('No cost yet as there is no characters')
        else:
            print(self.amount)
        
    def printDetail(self):
        print('Series Name: ',self.name)
        print('Release Year: ',self.year)
        print('Language: ',self.language)
        for i in self.character_list:
            for k in i:
                print(k)
            
    def addCharacter(self,chart):
        self.character_list.append((chart.role,chart.name))
        
class Character:
    def __init__(self,name,cata='Supporting character'):
        self.name=name
        self.role=cata


sherlock = Series("Sherlock Holmes", 2010)
print("1.============================================")
print(sherlock.character_list)
print("2.============================================")
sherlock.calculateCost()
print("3.============================================")
sherlock.printDetail()
print("4.============================================")
holmes = Character("Sherlock Holmes", "Main character")
watson = Character("James Watson", "Main character")
irene = Character("Irene Adler")
sherlock.addCharacter(holmes)
sherlock.addCharacter(watson)
sherlock.addCharacter(irene)
print("5.============================================")
sherlock.calculateCost()
print("6.============================================")
sherlock.printDetail()
print("7.============================================")
print(sherlock.character_list)
print("8.###############################################")
squid_games = Series("Squid Games", 2021, "Korean")
print("9.============================================")
print(squid_games.character_list)
print("10.============================================")
squid_games.calculateCost()
print("11.============================================")
squid_games.printDetail()
print("12.============================================")
seong = Character("Seong", "Main character")
kang = Character("Kang")
squid_games.addCharacter(seong)
squid_games.addCharacter(kang)
print("13.============================================")
squid_games.calculateCost()
print("14.============================================")
squid_games.printDetail()
print("15.============================================")
print(squid_games.character_list)
# Out:
# 1.============================================
# []
# 2.============================================
# No cost yet as there is no characters
# 3.============================================
# Series Name:  Sherlock Holmes
# Release Year:  2010
# Language:  English
# 4.============================================
# 5.============================================
# No cost yet as there is no characters
# 6.============================================
# Series Name:  Sherlock Holmes
# Release Year:  2010
# Language:  English
# Main character
# Sherlock Holmes
# Main character
# James Watson
# Supporting character
# Irene Adler
# 7.============================================
# [('Main character', 'Sherlock Holmes'), ('Main character', 'James Watson'), ('Supporting character', 'Irene Adler')]
# 8.###############################################
# 9.============================================
# []
# 10.============================================
# No cost yet as there is no characters
# 11.============================================
# Series Name:  Squid Games
# Release Year:  2021
# Language:  Korean
# 12.============================================
# 13.============================================
# No cost yet as there is no characters
# 14.============================================
# Series Name:  Squid Games
# Release Year:  2021
# Language:  Korean
# Main character
# Seong
# Supporting character
# Kang
# 15.============================================
# [('Main character', 'Seong'), ('Supporting character', 'Kang')]

# %%
1.============================================
No characters assigned yet
2.============================================
No cost yet as there is no characters
3.============================================
Series Name: Sherlock Holmes
Release Year: 2010
Language: English
4.============================================
5.============================================
Total Cost: 25000
6.============================================
Series Name: Sherlock Holmes
Release Year: 2010
Language: English
Main Characters(s):
Sherlock Holmes
James Watson
Supporting Characters(s):
Irene Adler
7.============================================
[('Sherlock Holmes', 'Main character'), ('James Watson', 'Main character'), ('Irene Adler', 'Supporting character')]
8.###############################################
9.============================================
No characters assigned yet
10.============================================
No cost yet as there is no characters
11.============================================
Series Name: Squid Games
Release Year: 2021
Language: Korean
12.============================================
13.============================================
Total Cost: 15000
14.============================================
Series Name: Squid Games
Release Year: 2021
Language: Korean
Main Characters(s):
Seong
Supporting Characters(s):
Kang
15.============================================
[('Seong', 'Main character'), ('Kang', 'Supporting character')]

# %%
class SDS:
    def __init__(self,year):
        

sds21 = SDS("2021")
print("*******************************************")
sds21.print_info()
print("1.================================")
s1 = Student("Maliha",21101001)
s1.print_info()
print("2.================================")
sds21.addStudent(s1)
sds21.print_info()
print("3.================================")
s2 = Student("Subha",21301001,"CSE", ["ENG091","MAT092"],3.48)
s2.print_info()
print("4.================================")
sds21.addStudent(s2)
sds21.print_info()
print("5.================================")
s3 = Student("Samiul",21305001,"MNS", ["ENG091","MAT092","PHY111"],3.01)
s4 = Student("Mohsina",21305023)
print("6.================================")
s3.print_info()
print("7.================================")
s4.print_info()
print("8.================================")
sds21.addStudent(s3,s4)
print("9.================================")
sds21.print_info()
print("10.================================")
s5 = Student("Nayla", 16101288, "BBS")
sds21.addStudent(s5)
print("11.================================")
sds21.print_info()

# %%
word=input()
str1=word[0]
count=1

for i in range(1,len(word)):
    if word[i] == word[i-1]:
        count+=1
        if count <= 3:
            str1+=word[i]
    else:
        str1+=word[i]
        count=1

print(str1)
# Out:
# AAAABBBBBBBBBBBB
# AAABBB

# %%
list1=[]
while True:
    sub=input()
    if sub != 'STOP':
        list1.append(sub)
    else:
        break
        
dict1={}        
for i in list1:
    k=i.split()
    if k[2] not in dict1:
        dict1[k[2]]= [k[0].upper()+' || '+k[1].upper()]
    else:
        dict1[k[2]].append(k[0].upper()+' || '+k[1].upper())

count=0
for k,p in dict1.items():
    print(k)
    count+=1
    for m in p:
        print(m)
    if count != len(dict1):
        print('===============')
# Out:
# cse111 quiz2 22/11/2021
# cse221 mid 29/11/2021
# cse320 quiz3 25/11/2021
# cse221 quiz2 22/11/2021
# STOP
# 22/11/2021
# CSE111 || QUIZ2
# CSE221 || QUIZ2
# ===============
# 29/11/2021
# CSE221 || MID
# ===============
# 25/11/2021
# CSE320 || QUIZ3

# %%
class Vehicle:
    
    def __init__(self,des,cata,name,dict2):
        self.bus=des
        self.cata=cata
        self.company=name
        if name in dict2:
            self.price=dict2[name]
        else:
            self.price=dict2['Others']
        self.dict1={'Passenger name':[],'Destination':[],'Ticket Price':[self.price]}        
        
    def addPassenger(self,other1,other2=None):
        print(other1.name,'has taken the',self.cata)
        self.dict1['Passenger name'].append(other1.name)
        self.dict1['Destination'].append(other1.destiny)

    def status(self):
        print('Details of',self.bus,self.cata,'of',self.company)
        print('Total Passengers:',len(self.dict1['Passenger name']))
        for i,k in self.dict1.items():
            for p in k:
                print(i,':',p)
                
class Passenger:
    def __init__(self,name,des=None):
        self.name=name
        if des != None:
            self.destiny=des
        else:
            print('Destination cannot be empty!')
        
    def calculateFare(self,other1,other2=None):
        print('Calculating fare for',self.name)
        
    def setDestination(self,place):
        self.destiny=place
        print('Destination of',self.name,'is updated to',self.destiny)

fareChart = {'SR Travels': 40, 'ENA': 50, 'Pathao': 200, 'Uber': 250, 'Hanif Paribahan': 45, 'Others': 90 }
v1 = Vehicle("Dhaka-123", "Bus", 'SR Travels', fareChart)
p1 = Passenger("Sam", "Dhaka")
print("1.===========================")
v1.addPassenger(p1)
print("2.===========================")
p1.calculateFare(v1)
print("3.===========================")
p2 = Passenger("John", "Dhaka")
p3 = Passenger("Bran")
print("4.===========================")
p3.setDestination("Chittagong")
print("5.===========================")
v1.addPassenger(p2, p3)
print("6.===========================")
p2.calculateFare(v1)
print("7.===========================")
p4 = Passenger("Mark", "Dhaka")
p5 = Passenger("Jack", "Khulna")
v1.addPassenger(p4, p5)
print("8.===========================")
p4.calculateFare(v1)
print("===========================")
v1.status()
v2 = Vehicle("Chittagong-798", "Car", "Uber", fareChart)
print("9.===========================")
v2.addPassenger(p1)
v2.addPassenger(p3)
print("10.===========================")
p3.calculateFare(v2)
print("11.===========================")
v2.status()
v3 = Vehicle("Khulna-997", "Car", "Obhai", fareChart)
v3.addPassenger(p5)
print("12.===========================")
p5.calculateFare(v3)
print("13.===========================")
v3.status()
# Out:
# 1.===========================
# Sam has taken the Bus
# 2.===========================
# Calculating fare for Sam
# 3.===========================
# Destination cannot be empty!
# 4.===========================
# Destination of Bran is updated to Chittagong
# 5.===========================
# John has taken the Bus
# 6.===========================
# Calculating fare for John
# 7.===========================
# Mark has taken the Bus
# 8.===========================
# Calculating fare for Mark
# ===========================
# Details of Dhaka-123 Bus of SR Travels
# Total Passengers: 3
# Passenger name : Sam
# Passenger name : John
# Passenger name : Mark
# Destination : Dhaka
# Destination : Dhaka
# Destination : Dhaka
# Ticket Price : 40
# 9.===========================
# Sam has taken the Car
# Bran has taken the Car
# 10.===========================
# Calculating fare for Bran
# 11.===========================
# Details of Chittagong-798 Car of Uber
# Total Passengers: 2
# Passenger name : Sam
# Passenger name : Bran
# Destination : Dhaka
# Destination : Chittagong
# Ticket Price : 250
# Jack has taken the Car
# 12.===========================
# Calculating fare for Jack
# 13.===========================
# Details of Khulna-997 Car of Obhai
# Total Passengers: 1
# Passenger name : Jack
# Destination : Khulna
# Ticket Price : 90

# %%
1.===========================
Sam has taken the Bus.
2.===========================
Calculating fare for Sam
3.===========================
Destination cannot be empty!
4.===========================
Destination of Bran is updated to Chittagong
5.===========================
John has taken the Bus.
This is an Inter-City Bus. Bran cannot take the Bus.
6.===========================
Calculating fare for John
7.===========================
Mark has taken the Bus.
This is an Inter-City Bus. Jack cannot take the Bus.
8.===========================
Calculating fare for Mark
===========================
Details of Dhaka-123 Bus of SR Travels:
Total Passengers: 3
Passenger name : Sam, Destination: Dhaka, Ticket Price: 40
Passenger name : John, Destination: Dhaka, Ticket Price: 40
Passenger name : Mark, Destination: Dhaka, Ticket Price: 40
9.===========================
This is an Inter-City Car. Sam cannot take the Car.
Bran has taken the Car.
10.===========================
Calculating fare for Bran
11.===========================
Details of Chittagong-798 Car of Uber:
Total Passengers: 1
Passenger name : Bran, Destination: Chittagong, Ticket Price: 250
Jack has taken the Car.
12.===========================
Calculating fare for Jack
13.===========================
Details of Khulna-997 Car of Obhai:
Total Passengers: 1
Passenger name : Jack, Destination: Khulna, Ticket Price: 90

# %%
word=input().split()
dict1={}

for i in word:
    count=0
    for k in range(0,len(word)):
        if i == word[k]:
            count+=1
    if count not in dict1:
        dict1[count]=[i]
    else:
        if i not in dict1[count]:
            dict1[count].append(i)
    
print(dict1)
# Out:
# cow cat cow ant elephant cow dog lion cat goat cow lion tiger elephant
# {4: ['cow'], 2: ['cat', 'elephant', 'lion'], 1: ['ant', 'dog', 'goat', 'tiger']}

# %%
class Passenger:
    bus_pass={'Passenger Name:':[],'Remaining balance:':[]}
    train_pass={'Passenger Name:':[],'Remaining balance:':[]}
    other_pass={'Passenger Name:':[]}
    
    def __init__(self,name,ticket,price=None):
        self.name=name
        if price != None:
            self.ticket=ticket
            self.price=price
            print(self.name,'is waiting for',self.ticket,'having',self.price,'taka in pocket')
        else:
            self.ticket=None
            self.price=ticket
            print(self.name,'Carol has',self.price,'taka in pocket.Please buy a ticket.')
            
        if self.ticket == 'Train Ticket':
            Passenger.train_pass['Passenger Name:'].append(self.name)
        elif self.ticket == 'Bus Ticket':
            Passenger.bus_pass['Passenger Name:'].append(self.name)
        else:
            Passenger.other_pass['Passenger Name:'].append(self.name)
            
    def buyTicket(self,ticket):
        self.ticket = ticket
        if self.ticket == 'Train Ticket':
            Passenger.train_pass['Passenger Name:'].append(self.name)
        else:
            Passenger.bus_pass['Passenger Name:'].append(self.name)
        
class TicketCounter:
    def __init__(self):
        print('This is a general bus and train ticket counter.')
        
    def servePassenger(self,*other):
        if len(other) == 3:
            print(other[0].name,'has bought',other[0].ticket,'ticket.')
            print(other[1].name,'has bought',other[1].ticket,'ticket.')
        value=0
        for i,k in dict1.items():
            if other.ticket == i:
                value=k
                
        value=other.price-value       
        if other.ticket == 'Train Ticket':
            Passenger.train_pass['Remaining balance:'].append(value)
        else:
            Passenger.bus_pass['Remaining balance:'].append(value)
            
    def showAllPassenger(self):
        print('Total passengers:',len(Passenger.train_pass['Passenger Name:'])+len(Passenger.bus_pass['Passenger Name:']))
        print('Bus passengers:',len(Passenger.bus_pass['Passenger Name:']))
        for i,k in Passenger.bus_pass.items():
            for p in k:
                print(i,p)
            
fareChart = {"Bus":550, "Train":600}
p1 = Passenger("Bob", "Bus Ticket",800)
p2 = Passenger("Simon", "Train Ticket", 950)
p3 = Passenger("David", "Train Ticket", 750)
p4 = Passenger("Carol", 1500)
print("1==============================")
tc = TicketCounter()
print("2==============================")
tc.servePassenger(p1,fareChart)
print("3==============================")
tc.servePassenger(p2,fareChart)
print("4==============================")
tc.servePassenger(p3, p4, fareChart)
print("5==============================")
p4.buyTicket("Train Ticket")
tc.servePassenger(p4,fareChart)
print("6==============================")
tc.showAllPassenger()
# Out:
#   File "<ipython-input-2-75de0f4a64a8>", line 35
#     def servePassenger(self,other1,other2=None,dict1):
#                        ^
# SyntaxError: non-default argument follows default argument

# %%
Bob is waiting for Bus having 800 taka in pocket.
Simon is waiting for Train having 950 taka in pocket.
David is waiting for Train having 750 taka in pocket.
Carol has 1500 taka in pocket.Please buy a ticket.
1==============================
This is a general bus and train ticket counter.
2==============================
Bob has bought Bus ticket.
3==============================
Simon has bought Train ticket.
4==============================
David has bought Train ticket.
Carol please buy a ticket first.
5==============================
Carol has bought Train ticket.
6==============================
Total passengers:4
Bus passengers:1
Passenger Name:Bob Remaining balance:250
Bus passengers:3
Passenger Name:Simon Remaining balance:350
Passenger Name:David Remaining balance:150
Passenger Name:Carol Remaining balance:900
# Out:
#   File "<ipython-input-1-3634eb4c43e6>", line 1
#     Bob is waiting for Bus having 800 taka in pocket.
#                    ^
# SyntaxError: invalid syntax

# %%
class Team:
    def __init__(self,name,win,lang='Spanish'):
        self.name=name
        self.win=win
        self.language=lang
        self.player_list='No players assigned yet'
        
    def addPlayer(self,other):
        if type(self.player_list) == str:
            self.player_list=[(other.name,other.position)]
        else:
            self.player_list.append((other.name,other.position))
        
    def printDetail(self):
        print('Team Name:',self.name)
        print('World Cup Win:',self.win)
        print('Language:',self.language)
    
    def calculateCost(self):
        if type(self.player_list) == str:
            print('No cost yet as there is no players')
        else:
            sum1=0
            for i in self.player_list:
                print(i)
                if i[1] == "Forward":
                    sum1+=500
                else:
                    sum1+=450
            print('Total Cost:',sum1)

class Player:
    def __init__(self,name,position="Forward"):
        self.name=name
        self.position=position
        
        
argentina = Team("Argentina", 2)
print("1.============================================")
print(argentina.player_list)
print("2.============================================")
argentina.calculateCost()
print("3.============================================")
argentina.printDetail()
print("4.============================================")
messi = Player("Messi")
maria = Player("Maria")
marcos = Player("Marcos", "Defender")
argentina.addPlayer(messi)
argentina.addPlayer(maria)
argentina.addPlayer(marcos)
print("5.============================================")
argentina.calculateCost()
print("6.============================================")
argentina.printDetail()
print("7.============================================")
print(argentina.player_list)
print("8.###############################################")
brazil = Team("Brazil", 5, "Portuguese")
print("9.============================================")
print(brazil.player_list)
print("10.============================================")
brazil.calculateCost()
print("11.============================================")
brazil.printDetail()
print("12.============================================")
silva = Player("Silva", "Defender")
neymar = Player("Neymar")
brazil.addPlayer(silva)
brazil.addPlayer(neymar)
print("13.============================================")
brazil.calculateCost()
print("14.============================================")
brazil.printDetail()
print("15.============================================")
print(brazil.player_list)
# Out:
# 1.============================================
# No players assigned yet
# 2.============================================
# No cost yet as there is no players
# 3.============================================
# Team Name: Argentina
# World Cup Win: 2
# Language: Spanish
# 4.============================================
# 5.============================================
# ('Messi', 'Forward')
# ('Maria', 'Forward')
# ('Marcos', 'Defender')
# Total Cost: 1450
# 6.============================================
# Team Name: Argentina
# World Cup Win: 2
# Language: Spanish
# 7.============================================
# [('Messi', 'Forward'), ('Maria', 'Forward'), ('Marcos', 'Defender')]
# 8.###############################################
# 9.============================================
# No players assigned yet
# 10.============================================
# No cost yet as there is no players
# 11.============================================
# Team Name: Brazil
# World Cup Win: 5
# Language: Portuguese
# 12.============================================
# 13.============================================
# ('Silva', 'Defender')
# ('Neymar', 'Forward')
# Total Cost: 950
# 14.============================================
# Team Name: Brazil
# World Cup Win: 5
# Language: Portuguese
# 15.============================================
# [('Silva', 'Defender'), ('Neymar', 'Forward')]

# %%
1.============================================
No players assigned yet
2.============================================
No cost yet as there is no players
3.============================================
Team Name: Argentina
World Cup Win: 2
Language: Spanish
4.============================================
5.============================================
Total Cost: 1450
6.============================================
Team Name: Argentina
World Cup Win: 2
Language: Spanish
Forwards:
Messi
Maria
Defenders:
Marcos
7.============================================
[('Messi', 'Forward'), ('Maria', 'Forward'), ('Marcos', 'Defender')]
8.###############################################
9.============================================
No players assigned yet
10.============================================
No cost yet as there is no players
11.============================================
Team Name: Brazil
World Cup Win: 5
Language: Portuguese
12.============================================
13.============================================
Total Cost: 950
14.============================================
Team Name: Brazil
World Cup Win: 5
Language: Portuguese
Forwards:
Neymar
Defenders:
Silva
15.============================================
[('Silva', 'Defender'), ('Neymar', 'Forward')]

# %%
word1=input()
word=''
for i in word1:
    if ord(i)>= 97 and ord(i)<=122:
        word+=chr(ord(i)-32)
    else:
        word+=i

list_word=[]
list_count=[]

for i in word:
    count=0
    for k in range(0,len(word)):
        if i == word[k]:
            count+=1
            
    if i not in list_word:
        list_word.append(i)
        list_count.append(count)

max_count=list_count[0]
count=0
for i in range(0,len(list_count)):
    if max_count < list_count[i]:
        max_count=list_count[i]
        count=i

list_word.remove(list_word[count])
list_count.remove(list_count[count])

max_count=list_count[0]
count1=0
for i in range(0,len(list_count)):
    if max_count < list_count[i]:
        count1=i
        
print(list_word[count1])
# Out:
# experience
# X

# %%
class SDS:
    mns_dict={}
    cse_dict={}
    
    def __init__(self,year):
        self.year=year
        print('School of Data and Sciences',self.year,'! Only CSE and MNS department students can be added.')
        
    def print_info(self):
        print('Number of CSE students:',len(SDS.cse_dict))
        print('Number of MNS students:',len(SDS.mns_dict))
        print('CSE Students',SDS.cse_dict)
        print('MNS Students',SDS.mns_dict)
        
    def addStudent(self,other1,other2=None):
        if other2 == None:
            if other1.dep == 'MNS':
                SDS.mns_dict[other1.id]=[other1.name,other1.cg,other1.list]
            elif other1.dep =='CSE':
                SDS.cse_dict[other1.id]=[other1.name,other1.cg,other1.list]
        else:
            if other1.dep == 'MNS':
                SDS.mns_dict[other1.id]=[other1.name,other1.cg,other1.list]
            if other1.dep =='CSE':
                SDS.cse_dict[other1.id]=[other1.name,other1.cg,other1.list]
            if other2.dep == 'MNS':
                SDS.mns_dict[other2.id]=[other2.name,other2.cg,other2.list]
            if other2.dep =='CSE':
                SDS.cse_dict[other2.id]=[other2.name,other2.cg,other2.list]
        
class Student:
    def __init__(self,name,id1,dep='MNS',list1=[],cg=0.00):
        self.name=name
        self.id=id1
        self.dep=dep
        self.list=list1
        self.cg=cg
        if self.dep != 'CSE' and self.dep != 'MNS':
            print(self.dep,'department student cannot be added to SDS')
    
    def print_info(self):
        print('Name:',self.name)
        print('ID:',self.id)
        print('Department:',self.dep)
        print('Courses:',self.list)
        print('CGPA:',self.cg)
    
    
sds21 = SDS("2021")
print("*******************************************")
sds21.print_info()
print("1.================================")
s1 = Student("Maliha",21101001)
s1.print_info()
print("2.================================")
sds21.addStudent(s1)
sds21.print_info()
print("3.================================")
s2 = Student("Subha",21301001,"CSE", ["ENG091","MAT092"],3.48)
s2.print_info()
print("4.================================")
sds21.addStudent(s2)
sds21.print_info()
print("5.================================")
s3 = Student("Samiul",21305001,"MNS", ["ENG091","MAT092","PHY111"],3.01)
s4 = Student("Mohsina",21305023)
print("6.================================")
s3.print_info()
print("7.================================")
s4.print_info()
print("8.================================")
sds21.addStudent(s3,s4)
print("9.================================")
sds21.print_info()
print("10.================================")
s5 = Student("Nayla", 16101288, "BBS")
sds21.addStudent(s5)
print("11.================================")
sds21.print_info()
# Out:
# School of Data and Sciences 2021 ! Only CSE and MNS department students can be added.
# *******************************************
# Number of CSE students: 0
# Number of MNS students: 0
# CSE Students {}
# MNS Students {}
# 1.================================
# Name: Maliha
# ID: 21101001
# Department: MNS
# Courses: []
# CGPA: 0.0
# 2.================================
# Number of CSE students: 0
# Number of MNS students: 1
# CSE Students {}
# MNS Students {21101001: ['Maliha', 0.0, []]}
# 3.================================
# Name: Subha
# ID: 21301001
# Department: CSE
# Courses: ['ENG091', 'MAT092']
# CGPA: 3.48
# 4.================================
# Number of CSE students: 1
# Number of MNS students: 1
# CSE Students {21301001: ['Subha', 3.48, ['ENG091', 'MAT092']]}
# MNS Students {21101001: ['Maliha', 0.0, []]}
# 5.================================
# 6.================================
# Name: Samiul
# ID: 21305001
# Department: MNS
# Courses: ['ENG091', 'MAT092', 'PHY111']
# CGPA: 3.01
# 7.================================
# Name: Mohsina
# ID: 21305023
# Department: MNS
# Courses: []
# CGPA: 0.0
# 8.================================
# 9.================================
# Number of CSE students: 1
# Number of MNS students: 3
# CSE Students {21301001: ['Subha', 3.48, ['ENG091', 'MAT092']]}
# MNS Students {21101001: ['Maliha', 0.0, []], 21305001: ['Samiul', 3.01, ['ENG091', 'MAT092', 'PHY111']], 21305023: ['Mohsina', 0.0, []]}
# 10.================================
# BBS department student cannot be added to SDS
# 11.================================
# Number of CSE students: 1
# Number of MNS students: 3
# CSE Students {21301001: ['Subha', 3.48, ['ENG091', 'MAT092']]}
# MNS Students {21101001: ['Maliha', 0.0, []], 21305001: ['Samiul', 3.01, ['ENG091', 'MAT092', 'PHY111']], 21305023: ['Mohsina', 0.0, []]}

# %%
School of Data and Sciences 2021! Only CSE and MNS department students can be added.
*******************************************
Number of CSE students: 0
Number of MNS students: 0
CSE Students {}
MNS Students {}
1.================================
Name: Maliha
ID: 21101001
Department: MNS
Courses: []
CGPA: 0
2.================================
Number of CSE students: 0
Number of MNS students: 1
CSE Students {}
MNS Students {21101001: ['Maliha', 0, []]}
3.================================
Name: Subha
ID: 21301001
Department: CSE
Courses: ['ENG091', 'MAT092']
CGPA: 3.48
4.================================
Number of CSE students: 1
Number of MNS students: 1
CSE Students {21301001: ['Subha', 3.48, ['ENG091', 'MAT092']]}
MNS Students {21101001: ['Maliha', 0, []]}
5.================================
6.================================
Name: Samiul
ID: 21305001
Department: MNS
Courses: ['ENG091', 'MAT092', 'PHY111']
CGPA: 3.01
7.================================
Name: Mohsina
ID: 21305023
Department: MNS
Courses: []
CGPA: 0
8.================================
9.================================
Number of CSE students: 1
Number of MNS students: 3
CSE Students {21301001: ['Subha', 3.48, ['ENG091', 'MAT092']]}
MNS Students {21101001: ['Maliha', 0, []], 21305001: ['Samiul', 3.01, ['ENG091', 'MAT092', 'PHY111']], 21305023: ['Mohsina', 0, []]}
10.================================
BBS department student cannot be added to SDS
11.================================
Number of CSE students: 1
Number of MNS students: 3
CSE Students {21301001: ['Subha', 3.48, ['ENG091', 'MAT092']]}
MNS Students {21101001: ['Maliha', 0, []], 21305001: ['Samiul', 3.01, ['ENG091', 'MAT092', 'PHY111']], 21305023: ['Mohsina', 0, []]}
