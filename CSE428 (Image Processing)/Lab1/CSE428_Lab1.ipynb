# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, transform, img_as_float

# %%
x = [1, 2, 4, 5, 7]
print(x)
# Out:
# [1, 2, 4, 5, 7]

# %%
for i in range(len(x)):
  x[i] = x[i] + 4
print(x)
# Out:
# [5, 6, 8, 9, 11]

# %%
x = np.array([1, 2, 4, 5, 7])
print(x)
# Out:
# [1 2 4 5 7]

# %%
x = x+4
print(x)
# Out:
# [ 5  6  8  9 11]

# %% [markdown]
# 2 3 4
#
# 5 6 7

# %%
# declare an array of 2 rows, 3 columns
x = np.array([[2,3,4],[5,6,7]])

# %%
print(x)
# Out:
# [[2 3 4]
#  [5 6 7]]

# %%
plt.imshow(x)

# %%
x = np.array([1, 2, 4, 5, 7])

# %%
print(x[3])
# Out:
# 5

# %%
print(x[-2])
# Out:
# 5

# %%
x = np.array([[2,3,4],[5,6,7]])
print(x[1][1])
print(x[1,1])
# Out:
# 6
# 6

# %%
x = np.array([[[2,3,4],[5,6,7]],[[2,3,4],[5,6,7]]])
print(x)
# Out:
# [[[2 3 4]
#   [5 6 7]]
#
#  [[2 3 4]
#   [5 6 7]]]

# %% [markdown]
# x[start:end] = [x[start], x[start+1], ....., x[end-1]]

# %%
x = np.array([1, 2, 4, 5, 7])
print(x[1:4])
# Out:
# [2 4 5]

# %%
x[-1:3:-1]
# Out:
# array([7])

# %%
print(x[1:-1])
# Out:
# []

# %% [markdown]
# x[start:end:step] = x[start], x[start+step], x[start+2*step],.... x[end-1]

# %%
print(x[0:5:1])
# Out:
# [1 2 4 5 7]

# %%
print(x[1:4:2])
# Out:
# [2 5]

# %%
print(x[::1])        # by default 0:len(x):1 >> ::1
                     # here 1 shows the step size or gaps
# Out:
# [1 2 4 5 7]

# %%
print(x[::-1])        # by default 0:len(x):1 >> ::1
                      # here -1 shows the step size or gaps (reverse)
# Out:
# [7 5 4 2 1]

# %%
print(x[::-2])        # by default 0:len(x):1 >> ::1
                      # here -2 shows the step size or gaps (reverse with 2 steps gap)
# Out:
# [7 4 1]

# %%
x = np.array([[2,3,4],[5,6,7]])
print(x)
# Out:
# [[2 3 4]
#  [5 6 7]]

# %%
print(x[0,])                 # [row, column]
# Out:
# [2 3 4]

# %%
print(x[:,-1:])              # ':' all row selected with first colon
                             # '-1:' means all column after -1 index (last column)
                             # As there is no column after last one so last column is printed
# Out:
# [[4]
#  [7]]

# %%
print(x[:,::2])             # ':' all row selected with first colon
                            # '::2' means all column after giving one column gap
# Out:
# [[2 4]
#  [5 7]]

# %% [markdown]
# `x[start:end]`
#
# `x[start:end:step]`
#
# `x[::]`
#
# start is not specified, 0
#
# end is not specified, len(x)
#
# step is not specified, 1

# %%
# boolean indexing

x = np.array([0, 1, -5, -4, 4, 5])

# %%
index = [False, False, True, True, False, False]

# %%
x[index]
# Out:
# array([-5, -4])

# %%
index = x < 0

# %%
index
# Out:
# array([False, False,  True,  True, False, False])

# %%
x[index]
# Out:
# array([-5, -4])

# %%
x[ x < 0 ]
# Out:
# array([-5, -4])

# %% [markdown]
# ## Slicing Summary
#
# `x[start:end:step] = [x[start], x[start+step], x[start+2*step], ... x[end-1]]`
#
# If `start` not specified, assumes `0`
#
# If `end` not specified, assumes `len(x)`
#
# If `step` not specified, assumes `1`
#
# **Boolean indexing**: `x[ind]` where `ind` is an array of `True` and `False` with the same size as `x`

# %%
x = np.array([4, 1, -1, 2, 4, 5])
print(x[1:4]) # [1, -1, 2]
print(x[1:]) # [1, -1, 2, 4, 5]
print(x[:4]) # []
print(x[:]) # []
print(x[2::2]) # []
print(x[:6:2]) # []
# Out:
# [ 1 -1  2]
# [ 1 -1  2  4  5]
# [ 4  1 -1  2]
# [ 4  1 -1  2  4  5]
# [-1  4]
# [ 4 -1  4]

# %% [markdown]
# # Image as NumPy array

# %%
x = np.random.rand(4, 5)
print(x)
print("shape -", x.shape)
# Out:
# [[0.25394042 0.3647609  0.25007746 0.71788989 0.46903026]
#  [0.95775656 0.67449457 0.9769526  0.72322692 0.01841267]
#  [0.90398924 0.29354864 0.07743626 0.79670156 0.36344918]
#  [0.83176855 0.60535181 0.34161383 0.30458674 0.62772562]]
# shape - (4, 5)

# %%
io.imshow(x)                      # represent a array in color chart
                                  # all color has intensity
                                  # the number of array is showed in color
plt.axis("off")
# Out:
# (-0.5, 4.5, 3.5, -0.5)

# %%
#height, width = x.shape[:2]
height = x.shape[0]
width = x.shape[1]
print("Height =", height)
print("Width =", width)
# Out:
# Height = 4
# Width = 5

# %%
x = np.random.rand(4, 5, 3)
height, width, nchannels = x.shape
print("Height =", height)
print("Width =", width)
print("Number of channels =", nchannels)
# Out:
# Height = 4
# Width = 5
# Number of channels = 3

# %%
print("Red Channel")
print(x[:, :, 0])

print("Green Channel")
print(x[:, :, 1])

print("Blue Channel")
print(x[:, :, 2])
# Out:
# Red Channel
# [[0.45668847 0.05331085 0.33958284 0.28745566 0.69090315]
#  [0.30830658 0.89926497 0.72040669 0.96071084 0.20777925]
#  [0.38727727 0.51366818 0.94018542 0.55373089 0.84905207]
#  [0.23658913 0.14037022 0.86052729 0.31326295 0.12671505]]
# Green Channel
# [[0.73452486 0.70130304 0.05706344 0.18777092 0.96619248]
#  [0.38231751 0.9785005  0.97088135 0.54939356 0.7267415 ]
#  [0.53126908 0.89189553 0.71639087 0.76983584 0.3537539 ]
#  [0.19520713 0.94156237 0.36448088 0.53009515 0.6516951 ]]
# Blue Channel
# [[0.94260743 0.43873357 0.93943624 0.35759719 0.37114873]
#  [0.66642841 0.9323733  0.1252418  0.00180862 0.72187736]
#  [0.66588142 0.22210702 0.65140573 0.21267314 0.25414675]
#  [0.95059339 0.61064249 0.78468239 0.04540324 0.55936532]]

# %%
io.imshow(x)
plt.axis("off")
# Out:
# (-0.5, 4.5, 3.5, -0.5)

# %%
plt.figure(figsize=(2, 2))
x_cropped = x[:3, :3, :]
io.imshow(x_cropped)
plt.axis("off")
# Out:
# (-0.5, 2.5, 2.5, -0.5)

# %% [markdown]
# # Real Digital Image

# %%
I = io.imread("cat_1.jpg")
height, width = I.shape[:2]
print("Height =", height)       # row numebr
print("Width =", width)         # column number
# Out:
# Height = 2657
# Width = 1771

# %%
plt.figure(figsize=(4, 4))
io.imshow(I)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %%
#    [red, green, blue]
'''  [[161 163 175]
      [162 164 176]
      [164 166 178]
      ...
      [155 140 121]
      [150 135 116]
      [143 130 113]] '''     # this is the first column or first height

# then all the column goes on and on after that
# there is total 1771 column (width) like this
# width = column number = 1771
# height = row number = 2657

print(I)
# Out:
# [[[161 163 175]
#   [162 164 176]
#   [164 166 178]
#   ...
#   [155 140 121]
#   [150 135 116]
#   [143 130 113]]
#
#  [[162 164 176]
#   [163 165 177]
#   [164 166 178]
#   ...
#   [155 140 121]
#   [150 135 116]
#   [144 131 114]]
#
#  [[165 165 177]
#   [166 166 178]
#   [167 167 179]
#   ...
#   [154 139 120]
#   [149 134 115]
#   [143 130 113]]
#
#  ...
#
#  [[ 23  22  18]
#   [ 23  22  18]
#   [ 23  22  17]
#   ...
#   [189 181 162]
#   [187 179 160]
#   [185 177 158]]
#
#  [[ 23  22  18]
#   [ 23  22  18]
#   [ 23  22  18]
#   ...
#   [189 181 162]
#   [187 179 160]
#   [185 177 158]]
#
#  [[ 22  21  19]
#   [ 22  21  17]
#   [ 22  21  17]
#   ...
#   [192 181 163]
#   [189 178 160]
#   [186 175 155]]]

# %%
x = I[0, 0]
y = I[0, -1]
print(x)
print(y)
# Out:
# [161 163 175]
# [143 130 113]

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Problem with **uint8**

# %%
x + y
# Out:
# array([48, 37, 32], dtype=uint8)

# %%
# Bad way of normalization
# I = I/255

# Good way
I = img_as_float(I)
I = img_as_float(I)

# %%
plt.figure(figsize=(3, 3))
io.imshow(I)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %% [markdown]
# ## Example 2

# %%
I = io.imread("tree_1.jpg")

# %%
I.shape
# Out:
# (662, 1000, 3)

# %%
height, width, nchannels = I.shape
print("Height =", height)
print("Width =", width)
print("Number of channels =", nchannels)
# Out:
# Height = 662
# Width = 1000
# Number of channels = 3

# %%
io.imshow(I)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Red channel
axes[0].imshow(I[:, :, 0], cmap="gray")
axes[0].axis("off")
axes[0].set_title("Red")

# Green channel
axes[1].imshow(I[:, :, 1], cmap="gray")
axes[1].axis("off")
axes[1].set_title("Green")

# Blue channel
axes[2].imshow(I[:, :, 2], cmap="gray")
axes[2].axis("off")
axes[2].set_title("Blue")
# Out:
# Text(0.5, 1.0, 'Blue')

# %%
# Only the left half of the image
I_cropped = I[:, :width//2, :]
io.imshow(I_cropped)
plt.axis("off")
# Out:
# (-0.5, 499.5, 661.5, -0.5)

# %%
# Only the  bottom half of the image
I_cropped = I[height//2:, :, :]
io.imshow(I_cropped)
plt.axis("off")
# Out:
# (-0.5, 999.5, 330.5, -0.5)

# %%
# flip along widht (with respect to y axis)
I_flipped = I[:, ::-1, :]
io.imshow(I_flipped)
plt.axis("off")
# Out:
# (-0.5, 999.5, 661.5, -0.5)

# %%
# flip along height (with respect to x axis)
I_flipped = I[::-1, :, :]
io.imshow(I_flipped)
plt.axis("off")
# Out:
# (-0.5, 999.5, 661.5, -0.5)

# %%
# Rotate 180 degree
I_rotated = I[::-1, ::-1, :]
io.imshow(I_rotated)
plt.axis("off")
# Out:
# (-0.5, 999.5, 661.5, -0.5)

# %% [markdown]
# # Example 3

# %%
I = io.imread("BracU_Logo.png")

# %%
io.imshow(I)

# %%
I.shape
# Out:
# (275, 300, 3)

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

# Red channel
axes[0].imshow(I[:, :, 0], cmap="gray")
axes[0].axis("off")
axes[0].set_title("Red")

# Green channel
axes[1].imshow(I[:, :, 1], cmap="gray")
axes[1].axis("off")
axes[1].set_title("Green")

# Blue channel
axes[2].imshow(I[:, :, 2], cmap="gray")
axes[2].axis("off")
axes[2].set_title("Blue")

# Alpha channel
axes[3].imshow(I[:, :, 3], cmap="gray")
axes[3].axis("off")
axes[3].set_title("Alpha")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-91-610c1a329dae> in <cell line: 19>()
#      17
#      18 # Alpha channel
# ---> 19 axes[3].imshow(I[:, :, 3], cmap="gray")
#      20 axes[3].axis("off")
#      21 axes[3].set_title("Alpha")
#
# IndexError: index 3 is out of bounds for axis 2 with size 3
